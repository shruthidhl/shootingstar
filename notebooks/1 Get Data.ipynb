# %% [markdown]
# ### This file fetches Linkedin Profile Links from Pre collected URL's, scrapes the profiles and then saves them to a cloud Mongo DB collection.

# %% [markdown]
# ### Do Not run Initial Code except Loading Libraries

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
import requests

# %%
import pymongo
from pymongo import MongoClient

#client = MongoClient('mongodb://127.0.0.1:27017/')

# Establish Connection with cloud server
conn = "mongodb+srv://jaiahujaa:Jaiahuja9$@cluster0.ehbij.mongodb.net/test"
client = MongoClient(conn)

# Connect to Database
db = client["Linkedin"]

# %% [markdown]
# import psycopg2

# %% [markdown]
# # LOADING PROFILE URL's - DONT RUN

# %%
# LOAD DATA

profile_df = pd.read_excel('Profile Links.xlsx')

# %%
profile_df
# Out:
#                                                   Links       Role  \
# 0             https://www.linkedin.com/in/saurabhkabadi  Developer
# 1                https://www.linkedin.com/in/amittiwari  Developer
# 2        https://www.linkedin.com/in/schezeenfazulbhoy/  Developer
# 3            https://www.linkedin.com/in/bhargavrathod/  Developer
# 4    https://www.linkedin.com/in/rahul-gupta-6a5967188/  Developer
# ..                                                  ...        ...
# 95   https://www.linkedin.com/in/jessica-guo-450a64132/  Developer
# 96               https://www.linkedin.com/in/das-utsav/  Developer
# 97              https://www.linkedin.com/in/prabhapaar/  Developer
# 98  https://www.linkedin.com/in/miaoqi-zhang-543088175/  Developer
# 99     https://www.linkedin.com/in/jai-ahuja-22b983113/  Developer
#
#     Experience      Remarks
# 0            0  Recent Grad
# 1            2          NaN
# 2            2          NaN
# 3            2          NaN
# ...

# %%
profile_df['Links'].iloc[20:40]
# Out:
# 20              https://www.linkedin.com/in/kashvisrivastava/
# 21       https://www.linkedin.com/in/ameya-bhaktha-247697157/
# 22               https://www.linkedin.com/in/vani-s-ba1706a5/
# 23                    https://www.linkedin.com/in/lnbsaurabh/
# 24                  https://www.linkedin.com/in/yovel-bursuk/
# 25        https://www.linkedin.com/in/gaurav-topre-69678b1ab/
# 26           https://www.linkedin.com/in/amrit-raj-4569121aa/
# 27                   https://www.linkedin.com/in/pritamprmnk/
# 28            https://www.linkedin.com/in/thanya-c-61197216b/
# 29        https://www.linkedin.com/in/hamza-raouzi-5254301ab/
# 30                    https://www.linkedin.com/in/anabakhtar/
# 31        https://www.linkedin.com/in/brian-thomas-a34919209/
# 32                    https://www.linkedin.com/in/ebandersen/
# 33      https://www.linkedin.com/in/mamafha-maanda-584727167/
# 34                https://www.linkedin.com/in/jakob-wolitzki/
# ...

# %% [markdown]
# # LINK SPLITTING - DONT RUN

# %%
#profile_df.Links.iloc[34].split('?')[0]
# Out:
# 'https://www.linkedin.com/in/jakob-wolitzki/'

# %%
for i in range(99):
    profile_df['Links'].iloc[i] = profile_df.Links.iloc[i].split('?')[0]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
profile_df.loc[99]
# Out:
# Links         https://www.linkedin.com/in/jai-ahuja-22b983113/
# Role                                                 Developer
# Experience                                                   2
# Remarks                                               No Match
# Name: 99, dtype: object

# %% [markdown]
# # SAVING THE LINKS - DONT RUN

# %%
#df1.to_excel('output1.xlsx', engine='xlsxwriter')  
#df1.to_excel("output.xlsx")

# %%
profile_df.to_excel('linkedin_profiles.xlsx')

# %% [markdown]
# # FECTHING SAMPLE DATA  - DONT RUN

# %%
proxy_api = requests.get(url = GET /proxycurl/api/v2/linkedin)

# %% [markdown]
# ### CHECKING OUT SAMPLE RESPONSE

# %%
# ITERATE HERE IN params URL parameter from the data



api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
api_key = 'FLJfoTCJ-Mf3Wfx_zKUPLQ'
header_dic = {'Authorization': 'Bearer ' + api_key}
params = {
    'url': 'https://www.linkedin.com/in/dheeraj-aggarwal-481b57117',
    'use_cache': 'if-present'}
response = requests.get(api_endpoint,
                        params=params,
                        headers=header_dic)

# %%
# ADD THIS RESULT TO SOME Document DB
response.json()
# Out:
# {'public_identifier': 'dheeraj-aggarwal-481b57117',
#  'profile_pic_url': 'https://media-exp1.licdn.com/dms/image/C5603AQGUm0xNGzJ_iw/profile-displayphoto-shrink_200_200/0/1597567970729?e=1635984000&v=beta&t=V39YZk0A_NpBV37vbItXskeOYPsZmfgdURVGsuPryHQ',
#  'background_cover_image_url': 'https://static-exp1.licdn.com/sc/h/5q92mjc5c51bjlwaj3rs9aa82',
#  'first_name': 'DHEERAJ',
#  'last_name': 'AGGARWAL',
#  'full_name': 'DHEERAJ AGGARWAL',
#  'occupation': 'Software Developer 2 at Oracle',
#  'headline': 'Software Developer 2 at Oracle | Ex-Paytm | ReactJs | DTU',
#  'summary': 'Software Developer at Oracle. M.Tech Computer Science & Engineering from DTU.\n\nWorking as a Front-End developer in agile methodology in cutting edge technologies to improve the end customer experience with our product. Highly focused and result oriented.Love to code and coding at the different online contest.',
#  'country': 'IN',
#  'country_full_name': 'India',
#  'city': 'Delhi',
#  'state': None,
# ...

# %% [markdown]
# # LOADING url's - BATCH 1 TO SCRAPE - DONT RUN

# %%
profiles_df = pd.read_excel('linkedin_profiles.xlsx')

# %%
profiles_list = []
for index,value in profiles_df.Links.items():
    profiles_list.append(value)

# %%
len(profiles_list)
# Out:
# 100

# %% [markdown]
# # PROFILE SCRAPING - BATCH 1 - DONT RUN

# %%
api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
api_key = 's01STHYjbd3_V3ynUxZhWQ'
header_dic = {'Authorization': 'Bearer ' + api_key}

# %% [markdown]
# ### DONT RUN FOLLOWING AGAIN AT ALL

# %%
for profile in profiles_list:
    params = {
    'url': profile,
    'use_cache': 'if-present'}
    response = requests.get(api_endpoint,
                        params=params,
                        headers=header_dic)
    li.insert_one(response.json())

# %%
# QUERYING ALL DATA
#for profile in li.find({}):
    #print(profile)

# %% [markdown]
# # Viewing  scraped raw data - RUN from here

# %%
db.list_collection_names()
# Out:
# ['Linkedin_Profiles']

# %%
# CONNECTING TO THE COLLECTION 
li = db['Linkedin_Profiles']

# %%
li
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-01.ehbij.mongodb.net:27017', 'cluster0-shard-00-02.ehbij.mongodb.net:27017', 'cluster0-shard-00-00.ehbij.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-2323ni-shard-0', ssl=True), 'Linkedin'), 'Linkedin_Profiles')

# %%
# LOADING RAW DATA
test = pd.DataFrame(list(li.find()))

# %%
test.head()
# Out:
#                         _id   code                   description  \
# 0  613a127d8e1c00ac916df51a  503.0  Scrape failed, please retry.
# 1  613a128d8e1c00ac916df51b    NaN                           NaN
# 2  613a128f8e1c00ac916df51c    NaN                           NaN
# 3  613a12b38e1c00ac916df51d  503.0  Scrape failed, please retry.
# 4  613a12ba8e1c00ac916df51e    NaN                           NaN
#
#                   name      public_identifier  \
# 0  Service Unavailable                    NaN
# 1                  NaN             amittiwari
# 2                  NaN      schezeenfazulbhoy
# 3  Service Unavailable                    NaN
# 4                  NaN  rahul-gupta-6a5967188
#
#                                                                                                                                                                     profile_pic_url  \
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   _id                           200 non-null    object
#  1   code                          20 non-null     float64
#  2   description                   20 non-null     object
#  3   name                          20 non-null     object
#  4   public_identifier             180 non-null    object
#  5   profile_pic_url               166 non-null    object
#  6   background_cover_image_url    156 non-null    object
#  7   first_name                    180 non-null    object
#  8   last_name                     180 non-null    object
#  9   full_name                     180 non-null    object
#  10  occupation                    158 non-null    object
#  11  headline                      173 non-null    object
# ...
